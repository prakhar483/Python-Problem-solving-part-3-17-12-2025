# %%
class Solution:
    def countBits(self, n):
        ans = []
        for i in range(n + 1):
            ans.append(bin(i).count('1'))
        return ans

# %%
sol = Solution()

n = 5
sol.countBits(n)
# Out:
# [0, 1, 1, 2, 1, 2]

# %%
sol.countBits(2)
# Out:
# [0, 1, 1]
